# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = '/content/drive/MyDrive/Kaggle_Datasets/CarbonEmissionIndia.csv'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(data)

# %%
df.head(15)
# Out:
#               States  ...  per capita CH4 (kg per person)
# 0     Andhra Pradesh  ...                           16.97
# 1          Arunachal  ...                           25.82
# 2              Assam  ...                           21.29
# 3              Bihar  ...                            9.59
# 4        Chattisgarh  ...                           22.37
# 5                Goa  ...                            7.62
# 6            Gujarat  ...                           12.26
# 7            Haryana  ...                           21.57
# 8   Himachal Pradesh  ...                           18.28
# 9    Jammu & Kashmir  ...                           14.42
# 10         Jharkhand  ...                           15.39
# 11         Karnataka  ...                           12.20
# 12            Kerala  ...                            4.52
# 13    Madhya Pradesh  ...                           15.15
# 14       Maharashtra  ...                            9.80
#
# [15 rows x 4 columns]

# %%
df.shape
# Out:
# (28, 4)

# %%
df.corr()
# Out:
#                                 per capita CO2 (kg per person)  ...  per capita CH4 (kg per person)
# per capita CO2 (kg per person)                        1.000000  ...                        0.044667
# per capita CO (kg per person)                         0.516380  ...                        0.135935
# per capita CH4 (kg per person)                        0.044667  ...                        1.000000
#
# [3 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['States', 'per capita CO2 (kg per person)',
#        'per capita CO (kg per person)', 'per capita CH4 (kg per person)'],
#       dtype='object')

# %%
df.describe()
# Out:
#        per capita CO2 (kg per person)  ...  per capita CH4 (kg per person)
# count                       28.000000  ...                       28.000000
# mean                       894.401071  ...                       16.549286
# std                        547.619397  ...                        6.599384
# min                        179.010000  ...                        4.520000
# 25%                        505.025000  ...                       11.830000
# 50%                        771.625000  ...                       15.690000
# 75%                       1058.092500  ...                       20.232500
# max                       2662.510000  ...                       33.380000
#
# [8 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 4 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   States                          28 non-null     object
#  1   per capita CO2 (kg per person)  28 non-null     float64
#  2   per capita CO (kg per person)   28 non-null     float64
#  3   per capita CH4 (kg per person)  28 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.0+ KB

# %%
df.hist(figsize=(10,10))
plt.show()

# %%
# Check for null value count
df.isnull().sum()
# Out:
# States                            0
# per capita CO2 (kg per person)    0
# per capita CO (kg per person)     0
# per capita CH4 (kg per person)    0
# dtype: int64

# %%
plt.figure(figsize=(20,7))
sns.lineplot(x= 'States', y="per capita CO2 (kg per person)", data=df ,marker='o')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(x= 'States', y="per capita CO (kg per person)", data=df ,marker='o')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(x= 'States', y="per capita CH4 (kg per person)", data=df ,marker='o')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.barplot(x= 'States', y="per capita CO2 (kg per person)", data=df )
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.barplot(x= 'States', y="per capita CO (kg per person)", data=df )
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.barplot(x= 'States', y="per capita CH4 (kg per person)", data=df )
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.barplot(x= "per capita CO (kg per person)", y="per capita CO2 (kg per person)", data=df, hue= 'States' )
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(x="States",y="per capita CO2 (kg per person)", data=df, color='lightblue',label='per capita CO2 (kg per person)' )
sns.lineplot(x="States",y="per capita CO (kg per person)", data=df, marker='o',label='per capita CO (kg per person)')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.barplot(x="States",y="per capita CO2 (kg per person)", data=df, color='lightblue')
sns.lineplot(x="States",y="per capita CH4 (kg per person)", data=df,marker='o',label='per capita CH4 (kg per person)' )
sns.lineplot(x="States",y="per capita CO (kg per person)", data=df, marker='o',label='per capita CO (kg per person)')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(x="States",y="per capita CO2 (kg per person)", data=df, color='lightblue')
sns.lineplot(x="States",y="per capita CH4 (kg per person)", data=df,marker='o',label='per capita CH4 (kg per person)' )
sns.lineplot(x="States",y="per capita CO (kg per person)", data=df, marker='o',label='per capita CO (kg per person)')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.heatmap(np.round(df.corr(),2),annot=True)
plt.show()
